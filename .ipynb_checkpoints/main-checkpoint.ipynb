# %% [markdown]
# # Stackoverflow
# TODO: intro
# First time here? run this [Another Cell](#another_cell)
#
# Download 300 pages each containing 30 questons from https://api.stackexchange.com/2.2/questions?page=1&order=desc&sort=activity&site=stackoverflow by executing
# ```!gulp stackoverflow --add```
#
# only 300 per day allowed. clicked on the link? 299 left ;)

# %%
# !gulp stackoverflow --add 300

# %%
# !gulp stackoverflow

# %% [markdown]
# TODO: write output like: Stackoverflow: 212MB, 1680 Files, 49860 Raw-Questions, 17058 duplicate, 17 invalid

# %% [markdown]
# ## Parse
# TODO: write.<br>
# use domjs to get html content, title, code, inlinecode, body. easy to extend.<br>
# Merged: 0MB, 32802 Valid-Questions.
#
# | Variable name          | Description                             | Comment |
# |-----------------------|-----------------------------------------|--------|
# |                 $id$  | Sample id                               | Question in case of StackpverflowO |
# |                 $score$  | Sample id                               | Question in case of StackpverflowO |
# |                 $isanswered$  | Sample id                               | Question in case of StackpverflowO |
# |                 $answere count$  | Sample id                               | Question in case of StackpverflowO |
# |              $created$  | Sample id                               | Question in case of StackpverflowO |
# |                 $tags$  | Sample id                               | Question in case of StackpverflowO |
# |      $title $  | Question features                       | Title, Body, Code |
# |      $body $       | Question features                       | Title, Body, Code |
# |      $code $       | Question features                       | Title, Body, Code |
# |      $inlinecode $ | Question features                       | Title, Body, Code |

# %%
# !gulp text
# Out:
# [06:36:00] Using gulpfile ~/Uni/KDDM2/KDDM2/gulpfile.js
# [06:36:00] Starting 'text'...
# [06:36:00] Starting '<anonymous>'...
# merged and converted
# [06:36:45] Finished '<anonymous>' after 46 s
# [06:36:45] Finished 'text' after 46 s

# %%
# %%HTML
# <iframe width="100%" height="800" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/stackoverflow.html"></iframe>
# Out:
# <iframe width="100%" height="800" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/stackoverflow.html"></iframe>

# %% [markdown]
# # Preprocessing
# TODO: write.<br>
# tasks: sentence, words nouns only (+lemma | stem | raw, +blacklist, +whitelist), ngrams. tf-idf<br>

# %%
# !gulp sentence

# %%
# !gulp term

# %%
# %%HTML
# <h2>Title term frequency, lemmatized, nouns only</h2>
# <iframe width="100%" height="300" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tfidf.html"></iframe>
# Out:
# <h2>Title term frequency, lemmatized, nouns only</h2>
# <iframe width="100%" height="300" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tfidf.html"></iframe>

# %% [markdown]
# ## Tfidf 32, 11, (body, code, title...)
# TODO: write.<br>
# Stackoverflow: 212MB, 1680 Files, 49860 Raw-Questions, 17058 duplicate, 17 invalid
#
# |....................................Data Type | Description                             | Comment |
# |--------------------------------------------:|-----------------------------------------|--------|
# |                         $c = T? B? C? I? $  | Question features                  | Title, Body, Code, Inlinecode |
# |      $tf = raw \lor bin \lor log \lor max$  | Term frequency variant                  |        |
# |               $df = raw \lor max \lor log$  | Document frequency variant              |        |
# |                            $cfg = c+tf+df$  | Configuration                           |        |
# |                   $s_{cfg} \in \mathbb{N}$  | Number of Samples                       | - unused |
# |                   $f_{cfg} \in \mathbb{N}$  | Number of terms                         | - tf<25 or df<5 |
# |                   $q_{cfg} \in \mathbb{N}$  | Number of classes                       | - unused |
# |                $S \in \mathbb{S}^{s}_{cfg}$ | Sample (Question) id                    | $s$ wrt. cfg|
# |                $F \in \mathbb{S}^{f}_{cfg}$ | Feature names                           | term or ngram |
# |       $Y \in \mathbb{B}^{s \times q}_{cfg}$ | sample class vector with same mask as X | $s$ and $q$ wrt. cfg |
# |       $R \in \mathbb{N}^{s \times f}_{cfg}$ | tf-raw                                  | $s$ and $f$ wrt. cfg |
# |       $X \in \mathbb{R}^{s \times f}_{cfg}$ | tf-idf                                  | $s$ and $f$ wrt. cfg |
#
#
#
# Merged: 0MB, 32802 Valid-Questions,
#
# tfdf (3x2x [title, body, code]), raw indices!

# %%
import pandas as pd
import numpy as np
def mklbl(prefix,n):
    return ["%s%s" % (prefix,i)  for i in range(n)]
   
TF = "RMBL"
IDF = "DSM"    
miindex = pd.MultiIndex.from_product(
    [ ['stackoverflow/'], 
      ['nltk/', 'sklearn/'], 
      ['stemmed/', 'lemmatized/', 'raw/'],
      ['C32/', 'C00/', 'C11/'], #combine("BLMR", "RCS")
      ['T', 'TB', 'TC', 'TBC']  #noreuse("TBCI")
    ],
    names=['source', 'vecimpl', 'wordtype', 'tf-idf', 'htmlfeature']
)  

#cells = np.arange(len(miindex)*len(micolumns)).reshape((len(miindex),len(micolumns)))
columns = ['s', 't', 'tr', 'X','XR','F', 'Y', 'T']
cells = np.arange(len(miindex)*len(columns)).reshape((len(miindex),len(columns)))
cells = np.zeros((len(miindex), len(columns)))
dfmi = pd.DataFrame(cells,index=miindex, columns=columns).sort_index().sort_index(axis=1)

print("dataframe", dfmi.shape)
print("cfgindex", miindex.shape)

select = dfmi.loc[(slice('stackoverflow/') ,slice('nltk/'), slice('lemmatized/'), slice('C00/'), slice('T')), :]
print("select",select.shape)

#for current in miindex:
#    print(current)

#print(filter('nltk', 'lemmatized', ['AD'], ['T']))

print(select.shape)
for current in select:
    print(current)


selectmore = dfmi.loc[('stackoverflow/' , 'nltk/', slice('lemmatized/'), slice(None), slice('T','TBC')), :]
print("select2", selectmore.shape)
selectmore
# Out:
# dataframe (72, 8)
# cfgindex (72,)
# select (1, 8)
# (1, 8)
# F
# T
# X
# XR
# Y
# s
# t
# tr
# select2 (9, 8)
#                                                          F    T    X   XR  \
# source         vecimpl wordtype    tf-idf htmlfeature
# stackoverflow/ nltk/   lemmatized/ C00/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0
#                                    C11/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0
#                                    C32/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0
#
#                                                          Y    s    t   tr
# source         vecimpl wordtype    tf-idf htmlfeature
# stackoverflow/ nltk/   lemmatized/ C00/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0
#                                    C11/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0
#                                    C32/   T            0.0  0.0  0.0  0.0
#                                           TB           0.0  0.0  0.0  0.0
#                                           TBC          0.0  0.0  0.0  0.0

# %%
import tfidftofile
tfidfplan = tfidftofile.Plan('stackoverflow', 'nltk', 'lemmatized', '32', slice('T', 'TB'))



wordtype =             [ 'lemmatized' ]
print(dfmi.loc[(slice(None) ,slice('nltk/'), slice('lemmatized/'), slice(None), slice('T')), :])

tfidfs =               [ [3, 2], [1, 1], [1, 0], [0, 1], [0, 0] ]       
#
#tfidftofile.runTfidf(wordtype, htmlfeatuercombo, htmlfeatuercomboDfTf, tfidfs)
# Out:
#                                                            F    T    X   XR  \
# source         tfidfimpl wordtype    tf-idf htmlfeature
# stackoverflow/ nltk/     lemmatized/ C00/   T            133  135  131  132
#                                      C11/   T            165  167  163  164
#                                      C32/   T            101  103   99  100
#
#                                                            Y    s    t   tr
# source         tfidfimpl wordtype    tf-idf htmlfeature
# stackoverflow/ nltk/     lemmatized/ C00/   T            134  128  129  130
#                                      C11/   T            166  160  161  162
#                                      C32/   T            102   96   97   98

# %%
import pandas as pd
import numpy as np
def mklbl(prefix,n):
    return ["%s%s" % (prefix,i)  for i in range(n)]
   
TF = "RMBL"
IDF = "DSM"
    
miindex = pd.MultiIndex.from_product(
    [ ['nltk', 'sklearn'], ['stemmed', 'lemmatized', 'raw'], ['LM', 'RD', 'MS'], ['T', 'TB', 'TC', 'TBC'] ],
    names=[ 'tfidfimpl', 'wordtype', 'tf-idf', 'htmlfeature']
)  

micolumns = pd.MultiIndex.from_tuples(
    [ ('X','$$X_{0}$$'), ('X','$$X_{23345}$$'), ('Y','$$Y_{android}$$'), ('Y','$$Y_{c\#}$$') ], 
    names=['matrix', 'term/class']
)

cells = np.arange(len(miindex)*len(micolumns)).reshape((len(miindex),len(micolumns)))
dfmi = pd.DataFrame(cells,index=miindex, columns=micolumns).sort_index().sort_index(axis=1)

print(dfmi.shape)
dfmi.loc[(slice('nltk'), slice('lemmatized'), slice('LM', 'MS'), slice('T','TB')), :]
# Out:
# (72, 4)
# matrix                                          X                \
# term/class                              $$X_{0}$$ $$X_{23345}$$
# tfidfimpl wordtype   tf-idf htmlfeature
# nltk      lemmatized LM     T                  48            49
#                             TB                 52            53
#                      MS     T                  80            81
#                             TB                 84            85
#
# matrix                                                Y
# term/class                              $$Y_{android}$$ $$Y_{c\#}$$
# tfidfimpl wordtype   tf-idf htmlfeature
# nltk      lemmatized LM     T                        50          51
#                             TB                       54          55
#                      MS     T                        82          83
#                             TB                       86          87

# %%
# %%HTML
# <h2>Removed df < 5, diff_df < 3, tf < 25, doclen < 5, preprocessing</h2>
# fig: title (cloud, termdist, chars, sentncecount, sentence lenght)
# fig: size plot after filter
# <iframe width="100%" height="800" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/stackoverflow.html"></iframe>
# Out:
# <h2>Removed df < 5, diff_df < 3, tf < 25, doclen < 5, preprocessing</h2>
# fig: title (cloud, termdist, chars, sentncecount, sentence lenght)
# fig: size plot after filter
# <iframe width="100%" height="800" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/stackoverflow.html"></iframe>

# %% [markdown]
# # Classification
# TODO: write.<br>
# \begin{equation}
#   Y=\left\{
#   \begin{array}{@{}ll@{}}
#     1, & \text{if}\ tag \in Sample \\
#     0, & \text{otherwise}
#   \end{array}\right.
# \end{equation}

# %% [markdown]
# ## Feature selection chi2, mi
# TODO: write.<br>
# featuresel 500 chi2, mi for each tag

# %%
tags = ['python', 'php', 'html', 'android', 'javascript', 'sql']

# %%
import pandas as pd
import numpy as np

X = np.random.randn(10, 3)
Y = np.random.randn(10, 3)
#df = pd.concat([], 
#    axis=1
#)
pd.DataFrame(X, columns=['$$X_{1}$$','$$X_{...1000...}$$','$$X_{3}$$']),
pd.DataFrame(Y, columns=['$$Y_{android}$$','$$Y_{...234...}$$','$$Y_{zoom}$$']),        
#df.iloc[0, 2] = np.nan
#df.loc[0, 'A'] = np.nan
df.style
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_810122f8_5e15_11e8_9228_7cdd902cfd33" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   $$X_{1}$$
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   $$X_{...}$$
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   $$X_{3}$$
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   $$Y_{android}$$
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   $$Y_{...}$$
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   $$Y_{zoom}$$
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_810122f8_5e15_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col0"
#                  class="data row0 col0" >
#                     0.765458
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col1"
#                  class="data row0 col1" >
#                     0.726563
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col2"
#                  class="data row0 col2" >
#                     -0.714102
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col3"
#                  class="data row0 col3" >
#                     -1.20667
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col4"
#                  class="data row0 col4" >
#                     0.87063
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row0_col5"
#                  class="data row0 col5" >
#                     -0.955302
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_810122f8_5e15_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col0"
#                  class="data row1 col0" >
#                     2.59313
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col1"
#                  class="data row1 col1" >
#                     0.187072
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col2"
#                  class="data row1 col2" >
#                     0.969451
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col3"
#                  class="data row1 col3" >
#                     -1.1073
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col4"
#                  class="data row1 col4" >
#                     -0.780922
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row1_col5"
#                  class="data row1 col5" >
#                     0.395757
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_810122f8_5e15_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col0"
#                  class="data row2 col0" >
#                     -0.77786
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col1"
#                  class="data row2 col1" >
#                     -0.123005
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col2"
#                  class="data row2 col2" >
#                     0.787587
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col3"
#                  class="data row2 col3" >
#                     -0.439318
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col4"
#                  class="data row2 col4" >
#                     0.445795
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row2_col5"
#                  class="data row2 col5" >
#                     1.18993
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_810122f8_5e15_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col0"
#                  class="data row3 col0" >
#                     -0.682646
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col1"
#                  class="data row3 col1" >
#                     -0.201709
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col2"
#                  class="data row3 col2" >
#                     0.359802
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col3"
#                  class="data row3 col3" >
#                     0.879658
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col4"
#                  class="data row3 col4" >
#                     0.0879427
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row3_col5"
#                  class="data row3 col5" >
#                     -0.534167
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_810122f8_5e15_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row4_col0"
#                  class="data row4 col0" >
#                     0.136624
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row4_col1"
#                  class="data row4 col1" >
#                     0.820448
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row4_col2"
#                  class="data row4 col2" >
#                     0.149854
#
#
#
#                 <td id="T_810122f8_5e15_11e8_9228_7cdd902cfd33row4_col3"
#                  class="data row4 col3" >
#                     -0.145363

# %%
# %%HTML
# Plot top 10, 20? feature +score for on tag
# <iframe width="100%" height="300" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tfidf.html"></iframe>
# Out:
# Plot top 10, 20? feature +score for on tag
# <iframe width="100%" height="300" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tfidf.html"></iframe>

# %% [markdown]
# ## Supervised Algorithms
# TODO: write.<br>

# %%
# %matplotlib inline
import classify
classify.run('32_title_body', 'chi2', ['python', 'android', 'html', 'php'])
# Out:
# FloatProgress(value=0.0, max=28.0)

# %% [markdown]
# list bad algos. reasons.

# %% [markdown]
# # Clustering
#
# TODO: write.<br>
# Load (X, Y, F) for 6 tags 'python',... and apply Classification Pipelines.<br>
# Pipeline: (pca, lda, svd, nmf) --> (agglo, kmeans, lda, gmm, dbscan) --> plotgrid(decomp x clusteralgo). <br>
#
# | Name | Data Type                           | Description                             | Comment |
# |------|-------------------------------------|-----------------------------------------|--------|
# | $s$  |                 $\in \mathbb{N}$  | Number Samples                          | random 2000   |
# | $t$  |                 $\in \mathbb{N}$  | Number of terms                         | reduced by projection |
# | $q$  |                 $\in \mathbb{S}$  | Analysed tags (labels)                  | ['android'] |
# | $F$  |          $\in \mathbb{S}^{t}_{q}$ | Feature names                           | useless     |
# | $Y$  |         $\in \mathbb{B}^{s}_{q}$  | Actual classes                          | just for visualisations |
# | $X$  | $\in \mathbb{R}^{s \times t}_{q}$ | tf-idf                                  | transformed  |
#
#
# find most simmilar to Y(q).

# %% [markdown]
# ## Decomposition
# TODO: write.<br>
#
# * $t \in \mathbb{N} \longmapsto t_{r} \in \mathbb{N}$
# * $F \in \mathbb{S}^{t}_{q} \longmapsto F \in \mathbb{S}^{t_{r}}_{q}$
# * $X \in \mathbb{R}^{s \times t}_{q} \longmapsto X_{r} \in \mathbb{R}^{s \times t_{r}}_{q}$
#
# internal dimension is for all projections the same,<br>
# but varies with cluster algo.
# most use 25, except DBscan, it used 5. Db scan has problems with dim > 50 in general.

# %% [markdown]
# ## Unsupervised Algorithms
#
# TODO: write.<br>
# applied to each composition
#
# Plot rrecision recall for each tag❌algo.

# %%
# %matplotlib inline
import cluster
decompositions = ['PCA', 'NMF', 'LDA', 'SVD'] # PCA NMF LDA SVD FastICA FA Dict
algos = ['Ward', 'K-Means', 'GMM', 'DBScan']  # Ward K-Means GMM DBScan Affinity
#node.update ('11_title_body', decompositions, algos, 1000, 'sql')
cluster.run('11_title', decompositions, algos, 2000, 'android')
# Out:
# FloatProgress(value=0.0, max=4.0)

# %%
find best matching cluster (maybe vary cluster count)

# %%
# %matplotlib inline
import cluster
decompositions = ['PCA', 'NMF', 'LDA', 'SVD'] # PCA NMF LDA SVD FastICA FA Dict
algos = ['Ward', 'K-Means', 'GMM', 'DBScan']  # Ward K-Means GMM DBScan Affinity
#node.update ('11_title_body', decompositions, algos, 1000, 'sql')
cluster.runPlotly('11_title', decompositions, algos, 2000, 'android')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~MichaelGlatzhofer/12.embed" height="250px" width="100%"></iframe>

# %%
import numpy as np
import plotly.plotly as py
import pandas as pd

df2 = pd.DataFrame({
    'A' : 1.,
    'B' : pd.Timestamp('20130102'),
    'C' : pd.Series(1,index=list(range(4)), dtype='float32'),
    'D' : np.array([3] * 4, dtype='int32'),
    'E' : pd.Categorical(["test","train","test","train"]),
    'F' : 'foo' 
})

df2.style
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   A
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   B
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   C
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   D
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   E
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   F
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col1"
#                  class="data row0 col1" >
#                     2013-01-02 00:00:00
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col2"
#                  class="data row0 col2" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col3"
#                  class="data row0 col3" >
#                     3
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col4"
#                  class="data row0 col4" >
#                     test
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row0_col5"
#                  class="data row0 col5" >
#                     foo
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col0"
#                  class="data row1 col0" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col1"
#                  class="data row1 col1" >
#                     2013-01-02 00:00:00
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col2"
#                  class="data row1 col2" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col3"
#                  class="data row1 col3" >
#                     3
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col4"
#                  class="data row1 col4" >
#                     train
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row1_col5"
#                  class="data row1 col5" >
#                     foo
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col0"
#                  class="data row2 col0" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col1"
#                  class="data row2 col1" >
#                     2013-01-02 00:00:00
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col2"
#                  class="data row2 col2" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col3"
#                  class="data row2 col3" >
#                     3
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col4"
#                  class="data row2 col4" >
#                     test
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row2_col5"
#                  class="data row2 col5" >
#                     foo
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col0"
#                  class="data row3 col0" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col1"
#                  class="data row3 col1" >
#                     2013-01-02 00:00:00
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col2"
#                  class="data row3 col2" >
#                     1
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col3"
#                  class="data row3 col3" >
#                     3
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col4"
#                  class="data row3 col4" >
#                     train
#
#
#
#                 <td id="T_ff491226_5dfa_11e8_9228_7cdd902cfd33row3_col5"
#                  class="data row3 col5" >
#                     foo
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# # Hierarchical Clustering (ward)
#
# TODO: write.<br>
# for each projection (svd, pca, lda) scipy.linkage(ward) algo <br>
#     --> for each node find decendantes, sum up raw tf, find top 3, safe tree

# %%
import hierarchy
hierarchy.run('11_title', ['SVD', 'LDA', 'PCA'], [10, 20], 'ground truth')
# Out:
# F (993,) ['.htaccess' '.net' '.net core' 'account' 'accuracy' 'action' 'active'
#  'activity' 'adapter' 'addition' 'address' 'admin' 'agent' 'ajax' 'alert'
#  'algorithm' 'align' 'allow' 'amazon' 'amount' 'analysis' 'analytics'
#  'anchor' 'android' 'android studio' 'angular' 'angular2' 'angularjs'
#  'animation' 'annotation' 'apache' 'apache spark' 'apis' 'apk' 'appium'
#  'approach' 'apps' 'arduino' 'area' 'arm' 'arraylist' 'arrow' 'asp.net'
#  'asp.net core' 'asp.net mvc' 'assembly' 'assertion' 'asset' 'assign'
#  'assignment' 'async' 'athena' 'attachment' 'attempt' 'audio' 'auth'
#  'auto' 'automation' 'average' 'aws' 'aws lambda' 'axis' 'azure'
#  'azure service' 'backend' 'background' 'background color' 'backup' 'bad'
#  'bar' 'base' 'base64' 'bash' 'bash script' 'batch' 'bean' 'behavior'
#  'behaviour' 'bigquery' 'binary' 'bind' 'binding' 'bit' 'bitmap' 'blank'
#  'blob' 'block' 'bluetooth' 'body' 'boost' 'boot' 'bootstrap' 'border'
#  'bot' 'bottom' 'bound' 'box' 'branch' 'break' 'browser' 'bucket' 'buffer'
#  'bug' 'build' 'builder' 'building' 'bundle' 'business' 'button'
#  'button click' 'byte' 'c' 'c++' 'cache' 'cakephp' 'calculate' 'calendar'
#  'callback' 'camel' 'camera' 'cant' 'canvas' 'capture' 'card' 'carousel'
#  'cassandra' 'cast' 'category' 'cause' 'center' 'centos' 'chain' 'channel'
#  'char' 'chart' 'chat' 'check' 'checkbox' 'checkboxes' 'checkout' 'child'
#  'chrome' 'circle' 'class' 'clause' 'cli' 'click' 'client' 'cloud'
#  'cluster' 'cmake' 'cmd' 'collection' 'color' 'columns' 'combobox' 'comma'
#  'command' 'comment' 'commit' 'compare' 'compile' 'compiler' 'component'
#  'composer' 'computer' 'condition' 'config' 'configure' 'conflict'
#  'connect' 'connection' 'console' 'constraint' 'consumer' 'contact'
#  'container' 'content' 'context' 'control' 'controller' 'conversion'
#  'convert' 'converter' 'cookie' 'cooky' 'copy' 'cordova' 'core' 'corner'
#  'cors' 'coverage' 'cpu' 'crash' 'creation' 'criterion' 'cross' 'css'
#  'csv' 'curl' 'cursor' 'customer' 'dashboard' 'database' 'dataframe'
#  'dataframes' 'dataset' 'datatables' 'datepicker' 'datetime' 'db2' 'debug'
#  'debugger' 'decimal' 'decorator' 'definition' 'delay' 'delete' 'delphi'
#  'dependency' 'deploy' 'deployment' 'design' 'desktop' 'detail' 'detect'
#  'detection' 'dev' 'developer' 'device' 'dialog' 'dictionary' 'digit'
#  'dimension' 'direction' 'directive' 'directory' 'disk' 'display'
#  'distance' 'div' 'django' 'django rest' 'dll' 'doc' 'docker'
#  'docker container' 'document' 'doesnt' 'dom' 'domain' 'dot' 'download'
#  'drag' 'drive' 'driver' 'drop' 'dropdown' 'drupal' 'duplicate' 'duration'
#  'dynamic' 'dynamodb' 'ec2' 'eclipse' 'edge' 'editor' 'edittext' 'effect'
#  'electron' 'email' 'empty' 'emulator' 'encryption' 'end' 'endpoint'
#  'engine' 'enter' 'entity' 'entity framework' 'entry' 'enum' 'equivalent'
#  'errors' 'es6' 'event' 'events' 'excel' 'excel vba' 'execute' 'execution'
#  'exists' 'exit' 'explorer' 'export' 'express' 'extension' 'extract'
#  'fabric' 'facebook' 'factory' 'fails' 'failure' 'false' 'fault' 'feature'
#  'feed' 'fetch' 'ffmpeg' 'filename' 'fill' 'filter' 'firebase'
#  'firebase database' 'firefox' 'firehose' 'firestore' 'fit' 'flag' 'flask'
#  'float' 'flow' 'flutter' 'focus' 'folder' 'font' 'footer' 'force'
#  'foreach' 'form' 'format' 'formatting' 'forms' 'formula' 'fragment'
#  'frame' 'framework' 'frequency' 'ftp' 'functions' 'gallery' 'game'
#  'gateway' 'gem' 'generate' 'generation' 'generator' 'generic' 'ggplot'
#  'ggplot2' 'git' 'github' 'gitlab' 'gmail' 'golang' 'google'
#  'google analytics' 'google cloud' 'google drive' 'google map'
#  'google maps' 'google play' 'google sheets' 'gradient' 'gradle' 'graph'
#  'graphql' 'grep' 'grid' 'gridview' 'groovy' 'group' 'gui' 'hadoop'
#  'handler' 'hang' 'hash' 'haskell' 'hdfs' 'header' 'height' 'heroku' 'hex'
#  'hibernate' 'hide' 'history' 'hive' 'home' 'hook' 'host' 'hour' 'hover'
#  'href' 'htaccess' 'html' 'html form' 'html tag' 'html5' 'http'
#  'http request' 'http status' 'httpclient' 'https' 'hyperlink' 'ibm'
#  'icon' 'ide' 'identity' 'iframe' 'ignore' 'iis' 'images' 'imageview'
#  'img' 'implement' 'import' 'include' 'info' 'injection' 'inline' 'insert'
#  'instagram' 'install' 'installer' 'instance' 'int' 'integer' 'intellij'
#  'intent' 'interface' 'internal' 'internet' 'interval' 'invalid' 'ionic'
#  'ios' 'iphone' 'issues' 'iterate' 'iteration' 'jar' 'java' 'javafx'
#  'javascript' 'jdbc' 'jenkins' 'jenkins pipeline' 'jest' 'jmeter' 'job'
#  'join' 'joomla' 'jpa' 'jquery' 'jquery ajax' 'json' 'jsp' 'junit'
#  'jupyter' 'jupyter notebook' 'jvm' 'jwt' 'kafka' 'kendo' 'kera' 'keras'
#  'kernel' 'keyboard' 'keyword' 'kinesis' 'kinesis firehose' 'kotlin'
#  'kubernetes' 'label' 'lambda' 'language' 'laravel' 'layer' 'layout'
#  'leak' 'left' 'letter' 'level' 'library' 'limit' 'link' 'linq' 'linux'
#  'listener' 'listview' 'load' 'loading' 'localhost' 'location' 'lock'
#  'log' 'logic' 'login' 'lookup' 'loss' 'mac' 'machine' 'macos' 'macro'
#  'magento' 'mail' 'management' 'manager' 'map' 'mapping' 'maps' 'marker'
#  'master' 'match' 'material' 'matlab' 'matplotlib' 'matrix' 'maven' 'max'
#  'mean' 'meaning' 'medium' 'member' 'memory' 'menu' 'merge' 'message'
#  'metadata' 'metric' 'microsoft' 'migration' 'min' 'minute' 'mismatch'
#  'mobile' 'mock' 'mockito' 'modal' 'mode' 'model' 'modify' 'module'
#  'mongo' 'mongodb' 'mongoose' 'month' 'mouse' 'move' 'multi' 'multiline'
#  'mvc' 'mysql' 'mysql database' 'mysql query' 'namespace' 'native'
#  'navbar' 'navigation' 'navigation bar' 'netbeans' 'network' 'nginx'
#  'node' 'node.js' 'nodejs' 'none' 'notebook' 'npm' 'nuget' 'null' 'numpy'
#  'oauth' 'oauth2' 'objects' 'odoo' 'office' 'offline' 'offset' 'online'
#  'opencv' 'openshift' 'operation' 'operator' 'option' 'oracle' 'others'
#  'outlook' 'override' 'package' 'packet' 'pagination' 'pair' 'panda'
#  'panda dataframe' 'pandas' 'panel' 'parallel' 'params' 'parent' 'parse'
#  'parser' 'partition' 'party' 'pas' 'pass' 'password' 'paste' 'path'
#  'payload' 'payment' 'pdf' 'percentage' 'period' 'perl' 'permission'
#  'phone' 'photo' 'php' 'picker' 'picture' 'pip' 'pipe' 'pipeline' 'pivot'
#  'pixel' 'place' 'plan' 'platform' 'play' 'player' 'plot' 'plugin' 'pod'
#  'point' 'pointer' 'policy' 'pool' 'popup' 'port' 'post' 'post request'
#  'postgres' 'postgresql' 'postman' 'power' 'powershell' 'practice'
#  'prediction' 'press' 'prestashop' 'prevent' 'preview' 'print' 'printer'
#  'problems' 'procedure' 'process' 'processing' 'processor' 'product'
#  'production' 'profile' 'progress' 'progress bar' 'promise' 'prompt'
#  'prop' 'protocol' 'protractor' 'provider' 'proxy' 'pull' 'purpose' 'push'
#  'pycharm' 'pyspark' 'python' 'python script' 'python3' 'query' 'queue'
#  'quote' 'r' 'rabbitmq' 'radio' 'radio button' 'rail' 'rails' 'random'
#  'range' 'raspberry' 'rate' 'razor' 'rds' 'react' 'react native' 'reactjs'
#  'read' 'reading' 'realm' 'record' 'rectangle' 'recursion' 'redirect'
#  'redis' 'redux' 'reference' 'refresh' 'regex' 'region' 'register'
#  'registry' 'regression' 'relation' 'release' 'reload' 'remote' 'remove'
#  'render' 'repeat' 'replace' 'repo' 'report' 'repository' 'request'
#  'require' 'reset' 'resolution' 'resource' 'response' 'rest'
#  'rest framework' 'retrieve' 'retrofit' 'reverse' 'rewrite' 'role' 'room'
#  'root' 'route' 'router' 'rows' 'ruby' 'ruby rails' 'rule' 'runtime'
#  'safari' 'sample' 'sas' 'save' 'scala' 'scale' 'scanner' 'scenario'
#  'scene' 'scheduler' 'schema' 'scope' 'scrapy' 'screen' 'script' 'scroll'
#  'scrollview' 'sdk' 'search' 'section' 'security' 'select' 'selection'
#  'selector' 'selenium' 'selenium webdriver' 'self' 'send' 'sentence'
#  'sequelize' 'sequence' 'series' 'service' 'services' 'servlet' 'session'
#  'setting' 'setup' 'shadow' 'shape' 'share' 'sharepoint' 'sheet' 'sheets'
#  'shell' 'shell script' 'shiny' 'shortcut' 'sierra' 'sign' 'signal'
#  'signature' 'simulator' 'single' 'singleton' 'site' 'skip' 'slide'
#  'slider' 'soap' 'socket' 'software' 'sonarqube' 'sort' 'sound' 'source'
#  'spark' 'speed' 'spinner' 'split' 'spring' 'spring boot' 'spring cloud'
#  'spring mvc' 'spring security' 'springboot' 'sql' 'sql database'
#  'sql query' 'sqlalchemy' 'sqlite' 'src' 'ssh' 'ssis' 'ssl' 'ssrs' 'stack'
#  'start' 'startup' 'state' 'status' 'std' 'stop' 'storage' 'store'
#  'stored' 'stream' 'streaming' 'struct' 'structure' 'studio' 'style' 'sub'
#  'subclass' 'submission' 'submit' 'subquery' 'subset' 'substring'
#  'success' 'sum' 'support' 'svg' 'svn' 'swagger' 'swift' 'swift4' 'switch'
#  'symbol' 'symfony' 'sync' 'syntax' 'system' 'tab' 'tables' 'tableview'
#  'tag' 'tags' 'target' 'task' 'tcp' 'telegram' 'template' 'tensor'
#  'tensorflow' 'term' 'terminal' 'testing' 'textbox' 'texture' 'textview'
#  'tfs' 'theme' 'thread' 'thymeleaf' 'timer' 'timestamp' 'title' 'tkinter'
#  'token' 'tomcat' 'tool' 'toolbar' 'tooltip' 'top' 'topic' 'trace'
#  'traffic' 'transfer' 'transform' 'transition' 'tree' 'treeview' 'trigger'
#  'trouble' 'twilio' 'txt' 'typeerror' 'typescript' 'ubuntu' 'uiview'
#  'unit' 'unity' 'unix' 'upgrade' 'upload' 'uri' 'url' 'urls' 'usage' 'usb'
#  'username' 'uwp' 'validate' 'validation' 'valueerror' 'var' 'vb.net'
#  'vba' 'vba excel' 'vector' 'vertex' 'video' 'view' 'vim' 'visual'
#  'visual studio' 'volume' 'vscode' 'vsts' 'vue' 'vue.js' 'vuejs' 'wait'
#  'warning' 'web' 'web service' 'webapi' 'webdriver' 'webpack' 'webpage'
#  'webservice' 'website' 'websocket' 'webview' 'week' 'weird' 'widget'
#  'width' 'wifi' 'window' 'windows' 'wix' 'wordpress' 'workbook' 'worker'
#  'workflow' 'worksheet' 'world' 'wpf' 'write' 'wso2' 'xamarin'
#  'xamarin forms' 'xaml' 'xampp' 'xcode' 'xml' 'xpath' 'xslt' 'year' 'yii2'
#  'youtube' 'zero' 'zip' 'zoom']
# nodemat (3581, 993)
# XL (3581, 993)
# zlen 3580 (3580, 4)
# all terms shape (1, 993)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-06a75a6c54fc> in <module>()
#       1 import hierarchy
# ----> 2 hierarchy.run('11_title', ['SVD', 'LDA', 'PCA'], [10, 20], 'ground truth')
#
# ~/Uni/KDDM2/KDDM2/hierarchy.py in run(tfidf, comp, dims, highlight)
#     106     print("F", F.shape, F)
#     107
# --> 108     createhierarchy(X_, XR, F, 'ward', 'SVD', 10)
#     109     createhierarchy(X_, XR, F, 'ward', 'SVD', 20)
#     110     createhierarchy(X_, XR, F, 'ward', 'LDA', 10)
#
# ~/Uni/KDDM2/KDDM2/hierarchy.py in createhierarchy(X_, XR, F, algo, preprocess, interndim)
#      93 def createhierarchy(X_, XR, F, algo, preprocess, interndim):
#      94     Z, n = calc(X_, algo, preprocess, interndim)
# ---> 95     nodeMat, tree = getRawCountMat(Z, XR, n, F)
#      96     jsonroot = convertd3json(XR, n, F, nodeMat, tree)
#      97
#
# ~/Uni/KDDM2/KDDM2/hierarchy.py in getRawCountMat(Z, XR, n, F)
#      46     allterms = sum(XR)
#      47     print("all terms shape", allterms.shape)
# ---> 48     print("all terms sum:", top(allterms, F, 10))
#      49     def visit(node):
#      50         if not node.is_leaf():
#
# ~/Uni/KDDM2/KDDM2/hierarchy.py in top(component, feature_names, n_top_words)
#      12 def top(component, feature_names, n_top_words):
#      13     #return " ".join([feature_names[i] for i in component.argsort()[:n_top_words]])
# ---> 14     return " ".join([feature_names[i] for i in component.argsort()[:-n_top_words - 1:-1]])
#      15
#      16 def postorder(node, visit):
#
# TypeError: sequence item 0: expected str instance, numpy.ndarray found

# %%
# %%HTML
# <iframe width="100%" height="700" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tree.html"></frame>
# Out:
# <iframe width="100%" height="700" frameBorder="0"
#     src="http://localhost:3002/dist/visualisations/tree.html"></frame>

# %% [markdown]
# # Install

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
#!gulp

# %%
# !pip3 install pandas

import plotly
plotly.tools.set_credentials_file(username='MichaelGlatzhofer', api_key='6fkzLsxb00TXcV1OmA52')
# Out:
# Traceback (most recent call last):
#   File "/usr/bin/pip3", line 9, in <module>
#     from pip import main
# ImportError: cannot import name 'main'
